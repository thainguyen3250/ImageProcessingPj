# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1=cv2.imread("C:\\Users\\thainguyen5484\\Downloads\\pic1.png")

img2=cv2.imread("C:\\Users\\thainguyen5484\\Downloads\\pic2.png")

# %%
img1.shape
# Out:
# (786, 910, 3)

# %%
img2.shape
# Out:
# (786, 910, 3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
plt.imshow(img1-img2)
