# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
##create white matrix
white_matrix=np.full([600,600,3],255)

white_matrix[100:500,110:200]=0

white_matrix[100:180,200:350]=0
white_matrix[260:340,200:350]=0
white_matrix[420:500,200:350]=0

white_matrix[130:270,350:420]=0
white_matrix[330:460,350:420]=0

# %%
plt.imshow(white_matrix)
