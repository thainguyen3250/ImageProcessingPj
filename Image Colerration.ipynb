# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image=cv2.imread("C:\\Users\\thainguyen5484\\Downloads\\wolf.jpg",0)

# %%
plt.imshow(image,cmap="gray")
plt.show()

# %%
image_new=cv2.bitwise_not(image)

# %%
plt.imshow(image_new,cmap="gray")
plt.show()
